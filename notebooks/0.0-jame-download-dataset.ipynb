# %% [markdown]
# Primero descargamos el dataset de [MusicNet](https://www.kaggle.com/datasets/imsparsh/musicnet-dataset)
# para esto hay que previamente solcitar una API de Kaggle (en la configuracion del perfil) y ponerla como variable de entorno `KAGGLE_API_TOKEN`

# %%
# %%bash
# cd ..
# cd data/raw
# kaggle datasets download imsparsh/musicnet-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/imsparsh/musicnet-dataset
# License(s): CC0-1.0
# ...
# 100%|██████████| 21.5G/21.5G [1:54:30<00:00, 3.36MB/s]

# %%
# %%bash
# cd ..
# cd data/raw
# unzip musicnet-dataset.zip -d ./
